# %%
pip install dash
# Out:
# Processing c:\users\nanda\appdata\local\pip\cache\wheels\83\5a\bb\71b5ab781de27039924ebc8b7670714ae5c9a436c9c9100954\dash-1.12.0-py3-none-any.whl
# Requirement already satisfied: future in c:\users\nanda\anaconda3\lib\site-packages (from dash) (0.18.2)
# Requirement already satisfied: dash-core-components==1.10.0 in c:\users\nanda\anaconda3\lib\site-packages (from dash) (1.10.0)
# Collecting plotly
#   Using cached plotly-4.7.0-py2.py3-none-any.whl (11.5 MB)
# Requirement already satisfied: flask-compress in c:\users\nanda\anaconda3\lib\site-packages (from dash) (1.5.0)
# Requirement already satisfied: dash-html-components==1.0.3 in c:\users\nanda\anaconda3\lib\site-packages (from dash) (1.0.3)
# Requirement already satisfied: Flask>=1.0.2 in c:\users\nanda\anaconda3\lib\site-packages (from dash) (1.1.1)
# Requirement already satisfied: dash-table==4.7.0 in c:\users\nanda\anaconda3\lib\site-packages (from dash) (4.7.0)
# Processing c:\users\nanda\appdata\local\pip\cache\wheels\58\74\07\ccdc4b119cc0314c5fead949457463176dfe3fb5bb86bb09c2\dash_renderer-1.4.1-py3-none-any.whl
# Requirement already satisfied: retrying>=1.3.3 in c:\users\nanda\anaconda3\lib\site-packages (from plotly->dash) (1.3.3)
# Requirement already satisfied: six in c:\users\nanda\anaconda3\lib\site-packages (from plotly->dash) (1.14.0)
# Requirement already satisfied: brotli in c:\users\nanda\anaconda3\lib\site-packages (from flask-compress->dash) (1.0.7)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\nanda\anaconda3\lib\site-packages (from Flask>=1.0.2->dash) (1.0.0)
# Requirement already satisfied: click>=5.1 in c:\users\nanda\anaconda3\lib\site-packages (from Flask>=1.0.2->dash) (7.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\nanda\anaconda3\lib\site-packages (from Flask>=1.0.2->dash) (2.11.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\nanda\anaconda3\lib\site-packages (from Flask>=1.0.2->dash) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\nanda\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.2->dash) (1.1.1)
# Installing collected packages: plotly, dash-renderer, dash
# Successfully installed dash-1.12.0 dash-renderer-1.4.1 plotly-4.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
import app

# %%
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd 
import app

# %%
external_stylesheets = ['https://usfmumaanalyticsteam.github.io/learn.css']

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bnandu247/bnandu247.github.io/master/amazon1.csv',encoding = 'latin1')

# %%
# Custom function used to generate a data table from a dataframe
def generate_table(dataframe, max_rows=16):
    return html.Table([
        html.Thead(
            html.Tr([html.Th(col) for col in dataframe.columns])
        ),
        html.Tbody([
            html.Tr([
                html.Td(dataframe.iloc[i][col]) for col in dataframe.columns
            ]) for i in range(min(len(dataframe), max_rows))
        ])
    ])

# %%
# Add content to the app layout
# Begin all content DIV
app.layout=html.Div([
    # Add your HTML tags to the content - notice a comma is added between HTML elements
    html.H1('Data Visualization and Story Telling'),
    html.Div([
        html.P('Amazon Forest Fire'),
    ]),
    # Begin of DIV surrounding both Tables
    html.Div([
    # Begin of First Table
    html.Table(style={'width':'100%'},
               # Begin of Table children
               children=[
                   #######################################################################
                   # Begin of First Tr
                 html.Tr(
                     #Begin Tr children
                     children=[
                         # Begin Th
                         
                         html.Th(style={'width':'30%'},
                             # Begin Th children
                             children=[
                                 html.H3('Graph 1')
                             # End of Th children   
                             ]
                         
                         # End of Th - Notice a comma is placed here to separate the next Th
                         ),
                         # Begin of Th
                         html.Th(style={'width':'70%'},
                             # Begin of Th children
                             children=[
                                 html.H3('Graph 2')
                             # End of Th children    
                             ]
                         
                         # End of Th
                         )
                         
                     # End of Tr children    
                     ]
                 # End of First Tr - Notice a comma is placed here to separate the next Tr
                 ),
                 #########################################################################
                 # Begin of Second Tr
                 html.Tr(
                     #Begin Tr children
                     children=[
                         # Begin Td
                         html.Td(
                             # Begin Td children
                             children=[
                                    # Display bar graph
                                    dcc.Graph(
                                    id='example-graph',
                                    figure={
                                        'data': [
                                            {'x': [1, 2, 3], 'y': [4, 1, 2], 'type': 'bar', 'name': 'N'},
                                            {'x': [1, 2, 3], 'y': [2, 4, 5], 'type': 'bar', 'name': 'M'},
                                        ],
                                        'layout': {
                                            'title': 'Graph 3'
                                        }
                                    }
                                # End of Chart 1
                                )
                              # End of Td children   
                             ]
                         
                         # End of Td - Notice a comma is placed here to separate the next Th
                         ),
                         # Being of Td
                         html.Td(
                             # Begin of Td children
                             children=[
                                 # Display plot graph use data from dataframe df
                                 dcc.Graph(
                                    id='life-exp-vs-gdp',
                                figure={
                                    'data': [
                                        dict(
                                            x=df[df['year'] == i]['year'],
                                            y=df[df['state'] == i]['state'],
                                            text=df[df['month'] == i]['month'],
                                            mode='markers',
                                            opacity=0.7,
                                            marker={
                                                'size': 15,
                                                'line': {'width': 0.5, 'color': 'white'}
                                            },
                                            name=i
                                        ) for i in df.state.unique()
                                    ],
                                    'layout': dict(
                                        xaxis={'type': 'log', 'title': 'X'},
                                        yaxis={'title': 'Y'},
                                        margin={'l': 40, 'b': 40, 't': 10, 'r': 10},
                                        legend={'x': 0, 'y': 1},
                                        hovermode='closest'
                                    ), 'layout': {
                                            'title': 'Graph 4'}
                                    # End of 2nd Inner DIV
                                    })
                           
                             # End of Td children    
                             ]
                         # End of Td
                         )
                     # End of Tr children    
                     ]
                 # End of Tr
                 )     
                #########################################################################                   
               #End of Table Children    
               ]
              # End of First Table - Notice a comma is placed here to separate the next Table
              ),
    
    #########################################################################################   
    # Begin of Second Table
    html.Table(style={'width':'100%'},
               children=[
                 #######################################################################
                 # Begin First Tr
                 html.Tr(
                     #Begin Tr children
                     children=[
                         # Begin Th
                         html.Th(style={'width':'30%'},
                             # Begin Th children
                             children=[
                                 html.H3('Grapgh 5')
                             # End of Th children   
                             ]
                         
                         # End of Th - Notice a comma is placed here to separate the next Th
                         ),
                         #Begin of Th
                         html.Th(style={'width':'10%'},
                             # Begin of Th children
                                 children=[
                                 # Nothing to display here, just a place holder in the column
                                 html.H2('')
                                 # End of Th children    
                                 ]
                             # End of Th - Notice a comma is placed here to separate the next Th
                         ),
                         # Begin of Th
                         html.Th(style={'width':'70%'},
                             # Begin of Th children
                             children=[        
                                    html.H3('Graph 6')
                                                               
                             # End of Th children    
                             ]
                         # End of Th
                         )
                     # End of Tr children    
                     ]
                 # End of First Tr
                 ),
                   
                ######################################################################
                # Begin of Second Tr
                 html.Tr(
                     #Begin Tr children
                     children=[
                         # Begin Td
                         html.Td(
                             # Begin Td children
                             children=[
                                    # Display a simple line graph
                                    dcc.Graph(
                                        id='g1', 
                                        figure={'data': [{'y': [1, 2, 3]}], 
                                                'layout': {'title': 'Graph 7'}})
                             # End of Td children   
                             ]
                         
                         # End of Td - Notice a comma is placed here to separate the next Th
                         ),
                         # Begin of Td
                         html.Td(style={'border':'1px solid black'},
                             # Begin of Td children
                             children=[
                                 # Display a large and important measure
                                 html.H2('A'),
                                 html.H2('B'),
                                 html.H2('C')
                             # End of Td children    
                             ]
                         # End of Td
                         ),
                         
                         # Begin of Td
                         html.Td(
                             # Begin of Td children
                             children=[
                                    # Execute custom generate_table function and display data
                                    # Use data from dataframe df2
                                    generate_table(df)
                             # End of Td children    
                             ]
                         # End of Td
                         )
                     # End of Tr children    
                     ]
                 # End of Second Tr
                 )     
               
               #######################################################################
               #End of Table Children    
               ]
              #########################################################################################
              # End of Second Table - Notice a comma is placed here to separate the next Content
              ),
    # End of DIV surrounding both Tables
    ]),
               
# End of all content DIV
])

# %%
# Run the app on the web server
if __name__ == '__main__':
    # Set debug to False. Some configurations are not setup for Debug
    app.run_server(debug=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-3dd582621161> in <module>
#       2 if __name__ == '__main__':
#       3     # Set debug to False. Some configurations are not setup for Debug
# ----> 4     app.run_server(debug=False)
#
# AttributeError: module 'app' has no attribute 'run_server'
